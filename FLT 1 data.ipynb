# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
FLT_1 = pd.read_excel('FLT 1 datasets.xlsx')
FLT_1
# Out:
#            t(s)  aoa (deg)  pitch (deg)  pitch speed (deg/s)  \
# 0       0.00000   1.978644     1.994105             0.009835
# 1       0.00012   1.978343     1.994686             0.009787
# 2       0.00024   1.978041     1.995267             0.009738
# 3       0.00036   1.977740     1.995847             0.009690
# 4       0.00048   1.977439     1.996428             0.009642
# ...         ...        ...          ...                  ...
# 99995  11.99940   2.391689     2.924688            -0.012253
# 99996  11.99952   2.391753     2.924688            -0.012253
# 99997  11.99964   2.391817     2.924688            -0.012253
# 99998  11.99976   2.391882     2.924688            -0.012253
# 99999  11.99988   2.391946     2.924688            -0.012253
#
#        true speed (m/s)  x acceleration (m/s2)  z acceleration (m/s2)  \
# 0             50.741865               1.053801              -7.403692
# 1             50.742590               1.054149              -7.405721
# ...

# %%
fig, ax = plt.subplots(7,1, figsize=(5, 10), dpi = 200)
count = 0
for data in FLT_1.columns:
    if data != "t(s)":
        ax[count].plot(FLT_1["t(s)"], FLT_1[data])
        ax[count].set_title(data)
        count += 1
plt.tight_layout()
plt.show()

# %%
FLT_1.get(["t(s)","aoa(deg)"])

# %%
a = FLT_1['t(s)']
b = FLT_1['aoa (deg)']
t = []
aoa = []
i = 50
for i in range (i):
    t.append(
        a.get (i)
    )
print (t)
k = 50
for k in range (k):
    aoa.append(
        b.get (k)
    )
print (aoa)
plt.title (f"huahuahua")
plt.plot (t , aoa , label = "hehe")
# Out:
# [0.0, 0.000119999999999926, 0.000239999999999848, 0.000360000000000042, 0.000480000000000216, 0.00060000000000004, 0.000720000000000211, 0.000840000000000173, 0.000960000000000103, 0.00108000000000007, 0.00120000000000011, 0.00132000000000035, 0.00144000000000013, 0.00155999999999997, 0.0016800000000003, 0.00180000000000008, 0.00192000000000021, 0.00203999999999988, 0.00215999999999988, 0.00227999999999996, 0.00240000000000022, 0.00252000000000035, 0.00264000000000011, 0.00275999999999993, 0.00288000000000001, 0.00299999999999996, 0.00312000000000025, 0.00323999999999998, 0.0033600000000002, 0.00348000000000023, 0.00360000000000009, 0.00372000000000009, 0.00383999999999993, 0.00396000000000021, 0.0040800000000001, 0.00420000000000023, 0.00432000000000041, 0.00444000000000012, 0.00455999999999997, 0.00467999999999987, 0.00480000000000002, 0.00492000000000001, 0.00504000000000021, 0.00516, 0.00528000000000007, 0.00540000000000016, 0.00551999999999998, 0.00564000000000016, 0.00575999999
# ...
