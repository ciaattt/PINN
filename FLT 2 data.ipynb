# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
FLT_2 = pd.read_excel('FLT 2 datasets.xlsx')
FLT_2
# Out:
#            t(s)  aoa(deg)  pitch (deg)  pitch speed (deg/sec)  \
# 0       0.00000  2.301349     2.204108               0.005427
# 1       0.00018  2.300746     2.206314               0.005446
# 2       0.00036  2.300143     2.208520               0.005466
# 3       0.00054  2.299540     2.210726               0.005485
# 4       0.00072  2.298937     2.212931               0.005504
# ...         ...       ...          ...                    ...
# 99995  17.99910  1.528265     3.327834               0.012054
# 99996  17.99928  1.528265     3.328812               0.012054
# 99997  17.99946  1.528265     3.329790               0.012054
# 99998  17.99964  1.528265     3.330768               0.012054
# 99999  17.99982  1.528265     3.331746               0.012054
#
#        true speed(m/s)  x acceleration (m/s2)  z acceleration (m/s2)  \
# 0            50.689410               1.007402              -9.854153
# 1            50.689410               1.006741              -9.855475
# ...

# %%
fig, ax = plt.subplots(7,1, figsize=(5, 10), dpi = 200)
count = 0
for data in FLT_2.columns:
    if data != "t(s)":
        ax[count].plot(FLT_2["t(s)"], FLT_2[data])
        ax[count].set_title(data)
        count += 1
plt.tight_layout()
plt.show()
