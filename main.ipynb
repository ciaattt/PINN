# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import random

# %%
def Y(W, b, noise = False):
    # float y_noise[5] = {}
    y_noise = []
    y_ideal = []

    # float x_noise[5] = {1,2,3,4,5}
    x_noise = [1,2,3,4,5]
    x_ideal = [1,2,3,4,5]
    
    for x in x_noise:
        print(x)
        # y_noise[i] = W * x + b + random.uniform(-1,1)
        y_noise.append(
            W * x + b + random.uniform(-1,1)
        )
        y_ideal.append(
            W * x + b 
        )
        print (y_noise)
    return x_ideal, y_ideal, x_noise, y_noise 
x_ideal, y_ideal, x_noise, y_noise  = Y(2, -1, True)
# Out:
# 1
# [0.539518111124998]
# 2
# [0.539518111124998, 3.3223609527955764]
# 3
# [0.539518111124998, 3.3223609527955764, 5.051349488559697]
# 4
# [0.539518111124998, 3.3223609527955764, 5.051349488559697, 7.951180250615526]
# 5
# [0.539518111124998, 3.3223609527955764, 5.051349488559697, 7.951180250615526, 9.913949943916824]

# %%
teks = "kontol"
plt.title(f"Ishiki pemalas {teks}")
plt.plot(x_ideal, y_ideal, label="Ideal")
plt.scatter(x_noise, y_noise, label="Data")
